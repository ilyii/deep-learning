# %% [markdown]
# # MNIST Digit Classification
# This notebook utilizes deep learning to classify the handwritten digits of the MNIST dataset.

# %% [markdown]
# ## Setup

# %%
import os
import random
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision 
from torch.utils.data import DataLoader, Dataset

# %%
SEED = 0
datapath = r"./data"
savepath = r"./output"
device = "cuda:0"

n_epochs = 50
batch_size_train = 256
batch_size_test = 256
learning_rate = 0.01
momentum = 0.5
val_freq = 10

in_dim = 784 #28*28 
hidden_dims = [100]
out_dim = 10

mean = 0.1307
std = 0.3081

# %%
os.makedirs(savepath, exist_ok=True)

# %% [markdown]
# ## Data

# %% [markdown]
# ## Model

# %% [markdown]
# ## Training Setup
#
# For training, SGD with momentum is used together with the negative log likelihood loss function.

# %% [markdown]
# ## Evaluation

# %%
print(f"Lowest loss found in epoch {np.argmin(logger.data['val']['loss'])+1} with loss: {np.min(logger.data['val']['loss']):.4f}")
print(f"Highest accuracy found in epoch {np.argmax(logger.data['val']['accuracy'])+1} with accuracy: {np.max(logger.data['val']['accuracy']):.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(f"Lowest loss found in epoch {np.argmin(logger.data['val']['loss'])+1} with loss: {np.min(logger.data['val']['loss']):.4f}")
#       2 print(f"Highest accuracy found in epoch {np.argmax(logger.data['val']['accuracy'])+1} with accuracy: {np.max(logger.data['val']['accuracy']):.4f}")
#
# File c:\Users\ihett\Workspace\deep-learning\.venv\Lib\site-packages\numpy\core\fromnumeric.py:1325, in argmin(a, axis, out, keepdims)
#    1238 """
#    1239 Returns the indices of the minimum values along an axis.
#    1240
#    (...)
#    1322 (2, 1, 4)
#    1323 """
#    1324 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1325 return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#
# ...

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax[0,0].plot(logger.data['train']['loss'], label='train')
ax[0,0].plot(logger.data['val']['loss'], label='test')
ax[0,0].set_title('Loss')
ax[0,0].set_xlabel('Epoch')
ax[0,0].set_ylabel('Loss')

ax[0,1].plot(logger.data['train']['accuracy'], label='train')
ax[0,1].plot(logger.data['val']['accuracy'], label='test')
ax[0,1].set_title('Accuracy')
ax[0,1].set_xlabel('Iteration')
ax[0,1].set_ylabel('Accuracy')

# ax[1,0].plot(train_stats['tp'], label='train')
# ax[1,0].plot(test_stats['tp'], label='test')
# ax[1,0].set_title('Accuracy')
# ax[1,0].set_xlabel('Iteration')
# ax[1,0].set_ylabel('Accuracy')

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
